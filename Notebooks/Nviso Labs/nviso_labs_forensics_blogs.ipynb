# %%
################################################################
# NVISO Labs Scraper                                           #
# Pulls Forensics blogs from the site!                         #
################################################################

import re
import requests
from bs4 import BeautifulSoup

EXCLUDE_WORDS = ["author", "wp-admin", "category", "#comments"]

def check_for_new_pages(url):

    page = 1
    while True:
        url = f"{base_url}/category/forensics/page/{page}" if page > 1 else base_url
        print(f"Scraping page: {page}")

        html = check_status(url)
        links = parse_links(html)

        if not links:
            break

        yield links
        page += 1

def check_status(url):

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36",
        "Accept": "application/html"
    }

    r = requests.get(url, headers=headers)
    
    if r.status_code == 200:
        return r.text
    else:
        return f"Error: {r.status_code}"

def parse_links(html):
    if not html:
        return []

    soup = BeautifulSoup(html, 'html.parser')

    links = []
    seen = set()

    pattern = re.compile(r"blog.nviso.eu")
    
    for link in soup.find_all('a', href=True):
        href = link['href']

        if not pattern.search(href):
            continue

        if any(word.lower() in href.lower() for word in EXCLUDE_WORDS):
            continue

        if href.rstrip("/") == "https://blog.nviso.eu":
            continue

        if href not in seen:
            links.append(href)
            seen.add(href)

    return links

if __name__ == "__main__":

    base_url = "https://blog.nviso.eu/category/forensics/"
    all_posts = []

    for page_links in check_for_new_pages(base_url):
        all_posts.extend(page_links)

    print(f"Scraped: {base_url} all found pages")
    print(f"\nFound {len(all_posts)} blog posts")

    print(all_posts)

    '''
    url = "https://blog.nviso.eu/category/blue-team/"
    html = check_status(url)
    get_links = parse_links(html)
    print(get_links)
    '''
# Out:
# Scraping page: 1
# Scraping page: 2
# Scraping page: 3
# Scraping page: 4
# Scraping page: 5
# Scraping page: 6
# Scraped: https://blog.nviso.eu/category/forensics/ all found pages
#
# Found 32 blog posts
# ['https://blog.nviso.eu/2025/10/02/what-did-the-attacker-read-mailitemaccessed-tells-you/', 'https://blog.nviso.eu/2025/06/19/tracking-historical-ip-assignments-with-defender-for-endpoint-logs/', 'https://blog.nviso.eu/2024/09/06/hunting-chromium-notifications/', 'https://blog.nviso.eu/2024/09/04/megasync-forensics-and-intrusion-attribution/', 'https://blog.nviso.eu/2024/08/02/from-evidence-to-advantage-leveraging-incident-response-artifacts-for-red-team-engagements/', 'https://blog.nviso.eu/2024/07/18/hunting-for-remote-management-tools/', 'https://blog.nviso.eu/2024/03/01/covert-tls-n-day-backdoors-sparkcockpit-sparktar/', 'https://blog.nviso.eu/2023/10/12/xor-known-plaintext-attacks/', 'https://blog.nviso.eu/2023/07/20/the-soc-toolbox-analyzing-autohotkey-compiled-executables/', 'https://blog.nviso.eu/2023/03/20/icedids-vnc-backdoors-dark-cat-anubis-keyhole/', 'https://blog.nviso.eu/2022/07/06/investigating-an-engineering-workstation-part-4/', 'https://blog.nviso.eu/2022/06/30/enforcing-a-sysmon-archive-quota/', 'https://blog.nviso.eu/2022/05/13/nviso-approved-as-apt-response-service-provider/', 'https://blog.nviso.eu/2022/05/13/nviso-approved-as-apt-response-service-provider/#respond', 'https://blog.nviso.eu/2022/04/20/investigating-an-engineering-workstation-part-3/', 'https://blog.nviso.eu/2022/03/30/investigating-an-engineering-workstation-part-2/', 'https://blog.nviso.eu/2022/03/30/investigating-an-engineering-workstation-part-2/#respond', 'https://blog.nviso.eu/2022/03/22/cobalt-strike-overview-part-7/', 'https://blog.nviso.eu/2022/03/15/investigating-an-engineering-workstation-part-1/', 'https://blog.nviso.eu/2022/03/11/cobalt-strike-memory-dumps-part-6/', 'https://blog.nviso.eu/2022/03/11/cobalt-strike-memory-dumps-part-6/#respond', 'https://blog.nviso.eu/2022/03/07/amcache-contains-sha-1-hash-it-depends/', 'https://blog.nviso.eu/2021/11/29/cobalt-strike-decrypting-dns-traffic-part-5/', 'https://blog.nviso.eu/2021/11/17/cobalt-strike-decrypting-obfuscated-traffic-part-4/', 'https://blog.nviso.eu/2021/11/03/cobalt-strike-using-process-memory-to-decrypt-traffic-part-3/', 'https://blog.nviso.eu/2021/10/27/cobalt-strike-using-known-private-keys-to-decrypt-traffic-part-2/', 'https://blog.nviso.eu/2021/10/21/cobalt-strike-using-known-private-keys-to-decrypt-traffic-part-1/', 'https://blog.nviso.eu/2021/09/09/kusto-hunting-query-for-cve-2021-40444/', 'https://blog.nviso.eu/2021/08/26/credential-harvesting-and-automated-validation-a-case-study/', 'https://blog.nviso.eu/2020/09/01/epic-manchego-atypical-maldoc-delivery-brings-flurry-of-infostealers/', 'https://blog.nviso.eu/2019/10/28/nessus-userassist-plugin/', 'https://blog.nviso.eu/2019/08/28/extracting-certificates-from-the-windows-registry/']
